# %% [markdown]
# Here is some text

# %%
#Here is some test code
import matplotlib.pyplot as plt
a = [1,2,3,4,5]
b = [5,4,3,2,1]
plt.plot(a,b)
plt.show()

# %%
c = [5,4,3,2,2]
plt.plot(a,c)
plt.show()

# %%
b[3]=4
b[4]=5
plt.plot(a,b)
plt.show()
